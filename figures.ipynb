# %%
import scipy.stats as st
import gzip
import pandas as pd

# %%
font = {'family' : 'sans-serif',
        'size'   : 20
    }
matplotlib.rc('font', **font)
matplotlib.rc('legend',**{'fontsize':14})
rcParams['figure.figsize'] = 10,8
rcParams['legend.fontsize'] = 20

# %%
T = 50 # tau
s = 0.05 # s = 0.01 # Kibota and Lynch 1996
H = 2
U = 0.0004 # Wielgoss et al. 2011
# U = 0.003 # Drake 1991
u = U * 0.2 / 1000 # Gordo, Perfeito, and Sousa 2011
N = 1e6
G = 25

# %%
print U < s
print s / u < N < (s / u) ** 2
# Out:
# True
# True

# %%
def save_figure(fig, plot_filename):
    full_filename = plot_filename + '.png'
    fig.savefig(full_filename)
    return full_filename

# %% [markdown]
# ## Genotype fitness

# %%
fig = figure(figsize=(6,6), dpi=300)
ax = fig.add_subplot(111)
b = ax.bar(range(4), [1,1-s,1-s,1+2*H], align="center")
ax.set_xticks(range(4))
ax.set_xticklabels(['ab','Ab','aB','AB'])
ax.set_yticks([0.9,1,1.1])
ax.set_ylim((0.9,1.1))
ax.set_ylabel('fitness')
tight_layout()

# %%
save_figure(fig, "fitness_bars")
# Out:
# 'fitness_bars.png'

# %% [markdown]
# ## Results

# %%
def appearance_cm_exact(T,U,u,s,H):
    return e**(-T*U) * (T*u)**2 * ( e**(-T*U/s) + 2 * e**(-T*u/s) / s)
def appearance_sim_exact(T,U,u,s,H):
    return u**2 * (e**(-U*(1+1/s)) + (2*T/s) * e**((-u/s)*T*U)) 
def fixation_cm_exact(T,U,u,s,H):
    return 2 * s*H / (1 + s*H)
def fixation_sim_exact(T,U,u,s,H):
    return 2 - 2 * (e**(U-U/s) + (1 - e**(-U/s)) * (1-s) * e**(U-T*U) ) / (1+s*H)
def adaptation_rate_cm_exact(T,U,u,s,H):
    return N * appearance_cm_exact(T,U,u,s,H) * fixation_cm_exact(T,U,u,s,H)
def adaptation_rate_sim_exact(T,U,u,s,H):
    return N * appearance_sim_exact(T,U,u,s,H) * fixation_sim_exact(T,U,u,s,H)
def appearance_cm_approx(T,U,u,s,H):
    return (1 - T * U) * (2 - T * U) * ((T*u)**2) / s
def appearance_sim_approx(T,U,u,s,H):
    return (1 - T * U) * (2 * T * u**2) / s
def fixation_cm_approx(T,U,u,s,H):
    return 2*s*H
def fixation_sim_approx(T,U,u,s,H):
    return 2*s*H + 2*(U**2 /s)*(T-1)*(1-s)
def adaptation_rate_cm_approx(T,U,u,s,H):
    return 2*N*H * (T * u) ** 2 * (1-T*U)*(2-T*U)
def adaptation_rate_sim_approx(T,U,u,s,H):
    return 4 * N * T * (u/s)  ** 2 * (1-T*U) * (s**2 * H + U**2 * (T-1) * (1-s))

# %%
with gzip.open(r"d:/workspace/ruggedsim/stochastic/appearances_pop1e%d.csv.gz" % log10(N)) as f:
    df = pd.read_csv(f)

# %%
xdf = df[df.U==U]
xdf = xdf[xdf.s==s]
xdf = xdf[xdf.pop_size==N]
xdf_sim = xdf[xdf.pi==1]
xdf_cm = xdf[xdf.pi==10]
print len(xdf)
print len(xdf_sim)
print len(xdf_cm)
# Out:
# 11942
# 6104
# 5838

# %%
taus = xdf['tau']
taus = taus.unique()
taus.sort()
taus
# Out:
# array([ 1,  2,  5,  7, 10, 15, 20, 28, 35, 42, 50], dtype=int64)

# %%
# ADAPTATION TIME
grouped_sim_fname = xdf_sim.groupby(['U','G','H','s','beta','pop_size','tau','pi','fname'])
funcs = {}
for k in xdf_sim.keys():
    funcs[k] = lambda x: x.unique()[0]
T_df = grouped_sim_fname.agg(funcs)
grouped_T = T_df.groupby(['U','G','H','s','beta','pop_size','tau','pi'])

adapt_time_mean_sim = grouped_T.T.aggregate(np.mean)
adapt_time_se_sim = grouped_T.T.aggregate(np.std) / sqrt(grouped_T.T.size())

# APPEARANCE TIME
grouped_sim = xdf_sim.groupby(['U','H','s','pi','tau','pop_size'])

app_time_mean_sim = grouped_sim.dif.aggregate(np.mean)
app_time_se_sim = grouped_sim.dif.aggregate(np.std) / np.sqrt(grouped_sim.dif.size())

app_prob_mean_sim = grouped_sim.dif.aggregate(lambda arr: (1.0/(N*arr)).mean())
app_prob_se_sim = grouped_sim.dif.aggregate(lambda arr: (1.0/(N*arr)).std()) / (grouped_sim.dif.size())

# FIXATION TIME
grouped_sim_fname = xdf_sim.groupby(['U','G','H','s','beta','pop_size','tau','pi','fname'])
funcs = {}
for k in xdf_sim.keys():
    if k == 'dif':
        funcs[k] = len
    else:
        funcs[k] = lambda x: x.unique()[0]
rho_df = grouped_sim_fname.agg(funcs)
grouped_rho = rho_df.groupby(['U','G','H','s','beta','pop_size','tau','pi'])

fix_time_mean_sim = grouped_rho.dif.aggregate(np.mean)
fix_time_se_sim = grouped_rho.dif.aggregate(np.std) / sqrt(grouped_rho.dif.size())

fix_prob_mean_sim = grouped_rho.dif.aggregate(lambda arr: (1.0/arr).mean())
fix_prob_se_sim = grouped_rho.dif.aggregate(lambda arr: (1.0/arr).std()) / sqrt(grouped_rho.dif.size())

# %% [markdown]
# ## Adaptation time figure

# %%
y5 = adapt_time_mean_sim[taus.tolist().index(5)]

fig = figure()
ax = fig.add_subplot(1,1,1)
ax.errorbar(taus, adapt_time_mean_sim, fmt='ko', label='Simulation', yerr=adapt_time_se_sim, linewidth=3)
ax.plot(taus, [1./adaptation_rate_sim_exact(TT,U,u,s,H) for TT in taus],'b-', linewidth=3, label='Approximation')
ax.set_xlabel(r"Mutation rate increase - $\tau$")
ax.set_ylabel('Adaptation Time - Generations')
ax.set_xlim((min(taus)-1,max(taus)+1))
ax.set_xticks([1]+range(10,60,10))
ax.legend(loc=1)
ax.grid(False, which='minor')
print yten
# Out:
# 3061916.27551

# %%
save_figure(fig,"adaptation_time_s_%.2f_logN_%d" % ( s, int(log10(N))))
# Out:
# 'adaptation_time_s_0.05_logN_6.png'

# %% [markdown]
# ## Appearance and fixation probabilities

# %%
import matplotlib.gridspec as gridspec

# %%
fig = figure(dpi=300,figsize=(8,10.66))
gs = gridspec.GridSpec(2,1, height_ratios=[2,1]) 

ax = plt.subplot(gs[0])

baseline = 1.0/(N*appearance_sim_exact(1,U,u,s,H))
ax.plot(taus, [(1.0/(N*appearance_sim_exact(TT,U,u,s,H)))/baseline for TT in taus],'b-', linewidth=3, label='Approximation')
baseline = app_time_mean_sim[0]
ax.errorbar(taus, app_time_mean_sim/baseline, fmt='ko', label='Simulation', yerr=app_time_se_sim/baseline, linewidth=3)

ax.set_ylabel('Appearance Time\nFold Change\n\n', horizontalalignment="center")
ax.set_xlim((min(taus)-1,max(taus)+1))
ax.set_xticks([1,10,20,30,40,50])
ax.set_ylim((0,1))
ax.set_yticks([0,0.1,0.25,0.5,0.75,1])
ax.axhline(y=0.1, xmax=10, color='k', ls='--')
ax.axvline(x=10, ymax=0.1, color='k', ls='--')
ax.legend(loc=1)

ax = plt.subplot(gs[1])

baseline = 1.0/(fixation_sim_exact(1,U,u,s,H))
ax.plot(taus, [(1.0/fixation_sim_exact(TT,U,u,s,H))/baseline for TT in taus],'b-', linewidth=3, label='Approximation')
baseline = fix_time_mean_sim[0]
ax.errorbar(taus, fix_time_mean_sim/baseline, fmt='ko', label='Simulation', yerr=fix_time_se_sim/baseline, linewidth=3, ecolor='k')

ax.set_ylabel('Fixation Time\nFold Change\n\n', horizontalalignment="center")
ax.set_xlabel(r"Mutation Rate Increase - $\tau$")
ax.set_xlim((min(taus)-1,max(taus)+1))
ax.set_xticks([1,10,20,30,40,50])
ax.set_ylim((0.5,1.5))
ax.set_yticks([0.5,1,1.5])
ax.grid(False, which='minor')

plt.tight_layout()

# %%
save_figure(fig, "app_fix_times_s_%.2f_logN_%d" % ( s, int(log10(N))))
# Out:
# 'app_fix_times_s_0.05_logN_6.png'

# %%
fig = figure(dpi=300,figsize=(15,5))

ax = plt.subplot(131)
ax.plot(taus, [(1.0/(N*appearance_sim_exact(TT,U,u,s,H))) for TT in taus],'b-', linewidth=3, label='Approximation')
ax.errorbar(taus, app_time_mean_sim, fmt='k-', label='Simulation', yerr=app_time_se_sim, linewidth=3)
ax.set_yscale('log')
ax.set_title("Waiting time\n")

ax = plt.subplot(132)
ax.plot(taus, [(1.0/(fixation_sim_exact(TT,U,u,s,H))) for TT in taus],'b-', linewidth=3, label='Approximation')
ax.errorbar(taus, fix_time_mean_sim, fmt='k-', label='Simulation', yerr=fix_time_se_sim, linewidth=3)
ax.set_yscale('log')
ax.set_title("Appearances attempts\n")

ax = plt.subplot(133)
ax.plot(taus, [(1.0/(adaptation_rate_sim_exact(TT,U,u,s,H))) for TT in taus],'b-', linewidth=3, label='Approximation')
ax.errorbar(taus, adapt_time_mean_sim, fmt='k-', label='Simulation', yerr=adapt_time_se_sim, linewidth=3)
compound_mean = array(fix_time_mean_sim)*array(app_time_mean_sim)
# http://math.stackexchange.com/questions/117763/multiplying-two-averages-what-to-do-with-the-deviations
compound_se = (array(fix_time_se_sim)**2)*(array(app_time_se_sim)**2)
compound_se += (array(app_time_se_sim)**2)*(array(fix_time_mean_sim)**2)
compound_se += (array(fix_time_se_sim)**2)*(array(app_time_mean_sim)**2)
compound_se = np.sqrt(compound_se)
ax.errorbar(taus, compound_mean, fmt='r-', label="fix*app", yerr=compound_se, linewidth=3)

ax.set_yscale('log')
ax.set_title("Adaptation time\n")

tight_layout()

# %%
save_figure(fig, "all_times_s_%.2f_logN_%d" % ( s, int(log10(N))))
# Out:
# 'all_times_s_0.05_logN_6.png'

# %% [markdown]
# ## Fitness landscapes

# %% [markdown]
# [PyDot](https://github.com/y-p/pydot): Python interface to [Graphviz Dot](http://www.graphviz.org/Documentation/dotguide.pdf). For this to work with IPython Notebook you need to install the code from GitHub rather than use `pip` etc.

# %%
import pydot
fontname = "Calibri"
G = 3

# %% [markdown]
# [Colors](http://colorbrewer2.org/index.php?type=sequential&scheme=YlGn&n=9) from [ColorBrewer](http://colorbrewer2.org/)

# %%
colors = '0xFFFFE5; 0xFFF7BC; 0xFEE391; 0xFEC44F; 0xFE9929; 0xEC7014; 0xCC4C02; 0x993404; 0x662506; 0x331608;'
colors = colors.split(';')
colors = [c.replace('0x','#').strip() for c in colors[:-1]]
colors
# Out:
# ['#FFFFE5',
#  '#FFF7BC',
#  '#FEE391',
#  '#FEC44F',
#  '#FE9929',
#  '#EC7014',
#  '#CC4C02',
#  '#993404',
#  '#662506',
#  '#331608']

# %%
class Genotype:
    def __init__(self, Aa, Bb, num_deleterious=0):
        self.Aa = Aa
        self.Bb = Bb
        self.num_deleterious = num_deleterious
        self.name = Aa+Bb
        if num_deleterious > -1:
            self.name += '/' + str(num_deleterious)
        if Aa == 'A' and Bb == 'B':
            self.fitness = (1 - s) ** num_deleterious * (1 + s * H)
        elif Aa == 'A' or Bb == 'B':
            self.fitness = (1 - s) ** (num_deleterious + 1)
        else:
            self.fitness = (1 - s) ** num_deleterious
        self.color = '#ffffff'
        self.sons = []
        if num_deleterious < G:
            self.sons.append(Genotype(Aa, Bb, num_deleterious + 1))
        if Aa.islower():
            self.sons.append(Genotype(Aa.upper(), Bb, num_deleterious))
        if Bb.islower():
            self.sons.append(Genotype(Aa, Bb.upper(), num_deleterious))
    def __repr__(self):
        return self.name
    
    def set_color(self, color):
        self.color = color
        
    def to_node(self):
        return pydot.Node(self.name, style="filled", fillcolor=self.color, fontname=fontname)
    
    def __eq__(self, other):
        return self.name == other.name
    
    def all_paths(self):
        if len(self.sons) == 0:
            return [self]
        sibs = self.sons + [self]
        for g in self.sons:            
            sibs.extend([s for s in g.all_paths() if s not in sibs])
        return sibs
    
    def is_leaf(self):
        return self.num_deleterious == G

# %%
ab = Genotype('a','b',0)
genotypes = sorted(ab.all_paths(), key=lambda x: x.name)
fitness = sorted(unique([g.fitness for g in genotypes]), reverse=True)
print len(fitness)
print fitness
fitness_to_color = { w:colors[i] for i,w in enumerate(fitness) }    
for g in genotypes:
    g.set_color(fitness_to_color[g.fitness])
# Out:
# 9
# [1.1000000000000001, 1.0449999999999999, 1.0, 0.99274999999999991, 0.94999999999999996, 0.94311249999999991, 0.90249999999999986, 0.85737499999999989, 0.81450624999999988]

# %% [markdown]
# ### Stochastic model

# %%
graph = pydot.Dot(graph_type='digraph',strict=True)
for g in genotypes:
    graph.add_node(g.to_node())
    
for g in genotypes:
    if g.is_leaf():
        node = pydot.Node(g.name + '...')
        node.set_label('...')
        node.set_style('filled')
        node.set_fillcolor(colors[-1])
        node.set_fontcolor('#CCCC9A')
        node.set_fontname(fontname)
        graph.add_node(node)
        edge = pydot.Edge(g.to_node(), node)
        edge.set_label('U')
        edge.set_style('dashed')
        edge.set_fontname(fontname)
        graph.add_edge(edge)
    for gs in g.sons:
        edge = pydot.Edge(g.to_node(), gs.to_node())
        if g.name[:2] == gs.name[:2]:
            edge.set_label('U')
            edge.set_style('dashed')

        else:
            edge.set_label(u"\u03BC")
        edge.set_fontname(fontname)
        graph.add_edge(edge)
graph.set_ratio(1)
graph

# %%
graph.set_dpi(200)
graph.write_png("fitness_landscape_stochastic_model.png")
! fitness_landscape_stochastic_model.png

# %% [markdown]
# ### Analytic model

# %%
def no_del(node):
    node.set_name(node.get_name()[1:3])
    return node

# %%
graph = pydot.Dot(graph_type='digraph',strict=True)
rip = pydot.Node("RIP", style="filled", fillcolor=colors[-3], fontname=fontname)
graph.add_node(rip)
for g in [x for x in genotypes if x.num_deleterious == 0]:
    graph.add_node(no_del(g.to_node()))

for g in [x for x in genotypes if x.num_deleterious == 0]:
    for gs in [x for x in g.sons if x.num_deleterious == 0]:
        edge = pydot.Edge(no_del(g.to_node()), no_del(gs.to_node()))
        edge.set_label(u"\u03BC")
        edge.set_fontname(fontname)
        graph.add_edge(edge)
    edge = pydot.Edge(no_del(g.to_node()), rip)
    edge.set_label('U')
    edge.set_style('dashed')
    edge.set_fontname(fontname)
    graph.add_edge(edge)

graph.set_ratio(1)
graph

# %%
graph.set_dpi(150)
graph.write_png("fitness_landscape_analytic_model.png")
! fitness_landscape_analytic_model.png

# %% [markdown]
# ### Colormap

# %%
cmap = matplotlib.colors.ListedColormap(list(reversed(colors)))
bounds = [1 + s * H] + [(1 - s) ** i for i in range(len(colors) - 1)]
bounds.reverse()
norm = matplotlib.colors.BoundaryNorm(bounds, cmap.N)

# %%
np.random.seed(101)
zvals = np.random.rand(100, 100) * (1 + s * H)

# %%
fig = figure(figsize=(20,10))
ax = plt.subplot(111)
im = ax.imshow(zvals, interpolation='nearest', origin='lower', cmap=cmap, norm=norm)
cb = fig.colorbar(im, format=FormatStrFormatter('${%.2f}$'))

for t in cb.ax.get_yticklabels():
     t.set_fontsize(20)

# %%
fig.savefig("fitness_landscape_colorbar.png")
! fitness_landscape_colorbar.png

# %% [markdown]
# ## QRCode

# %%
import qrcode # https://github.com/lincolnloop/python-qrcode

# %%
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_H,
    box_size=8,
    border=0,
)
qr.add_data("http://www.yoavram.com/")
qr.make(fit=True)

img = qr.make_image()
img.save("qrcode.png")
! qrcode.png
